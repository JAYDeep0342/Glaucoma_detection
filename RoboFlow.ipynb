# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sCjMu4xCboohokOCUGdU")
project = rf.workspace("gautam-inzfs").project("coco-me1p0-8qtqr")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 144.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.90
#     Uninstalling opencv-python-headless-4.13.0.90:
#       Successfully uninstalled opencv-python-headless-4.13.0.90
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Coco-1 in yolov11:: 100%|██████████| 10012/10012 [00:01<00:00, 6825.73it/s]

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model=YOLO("yolo11n.pt")
result = model.train(data="/content/Coco-1/data.yaml", epochs=14, imgsz=640)
# Out:
# ...
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
result= model("/content/Coco-1/train/images/000000000139_jpg.rf.136a49335ee169eb2ddb3ae5b5a0adcf.jpg")
# Out:
# image 1/1 /content/Coco-1/train/images/000000000139_jpg.rf.136a49335ee169eb2ddb3ae5b5a0adcf.jpg: 448x640 4 chairs, 1 clock, 1 dining table, 1 person, 3 potted plants, 3 tvs, 1 vase, 57.4ms
# Speed: 2.8ms preprocess, 57.4ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
